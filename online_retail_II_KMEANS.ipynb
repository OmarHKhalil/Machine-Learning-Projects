# %%
import pandas as pd
import numpy as np
import os
import opendatasets as od
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pd.set_option('display.max_rows', 150)
pd.set_option('display.max_columns', 999)

# %%
df = pd.read_excel('./online_retail_II.xlsx', sheet_name=0)
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %% [markdown]
# # Cleaning Data

# %%
df.info()
#   يوجد عامود واحد يحتوي على قيم فارغه
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  datetime64[ns]
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 32.1+ MB

# %%
df['Country'].value_counts()
#  الاعمد الفريده غير موجوده
# Out:
# Country
# United Kingdom          485852
# EIRE                      9670
# Germany                   8129
# France                    5772
# Netherlands               2769
# Spain                     1278
# Switzerland               1187
# Portugal                  1101
# Belgium                   1054
# Channel Islands            906
# Sweden                     902
# Italy                      731
# Australia                  654
# Cyprus                     554
# Austria                    537
# Greece                     517
# United Arab Emirates       432
# Denmark                    428
# Norway                     369
# Finland                    354
# Unspecified                310
# USA                        244
# Japan                      224
# Poland                     194
# Malta                      172
# Lithuania                  154
# Singapore                  117
# RSA                        111
# Bahrain                    107
# Canada                      77
# ...

# %%
df.describe().T
#  يوجد قيم متطرفه
#  يوجد قيم سالبه في السعر والكميه وهذا شيء خاطء يجب التعامل معه
# Out:
#                 count                           mean                  min  \
# Quantity     525461.0                      10.337667              -9600.0
# InvoiceDate    525461  2010-06-28 11:37:36.845017856  2009-12-01 07:45:00
# Price        525461.0                       4.688834            -53594.36
# Customer ID  417534.0                   15360.645478              12346.0
#
#                              25%                  50%                  75%  \
# Quantity                     1.0                  3.0                 10.0
# InvoiceDate  2010-03-21 12:20:00  2010-07-06 09:51:00  2010-10-15 12:45:00
# Price                       1.25                  2.1                 4.21
# Customer ID              13983.0              15311.0              16799.0
#
#                              max          std
# Quantity                 19152.0    107.42411
# InvoiceDate  2010-12-09 20:01:00          NaN
# Price                   25111.09   146.126914
# ...

# %%
df.describe(include='O').T
# Out:
#               count unique                                 top    freq
# Invoice      525461  28816                              537434     675
# StockCode    525461   4632                              85123A    3516
# Description  522533   4681  WHITE HANGING HEART T-LIGHT HOLDER    3549
# Country      525461     40                      United Kingdom  485852

# %%
df.duplicated().sum()
# يوجد قيم مكرره يجب التعامل معها
# Out:
# 6865

# %%
df.InvoiceDate.dt.year.value_counts()
# Out:
# InvoiceDate
# 2010    480233
# 2009     45228
# Name: count, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis and Visualization

# %%
df[df['Customer ID'].isna()]
#  نلاحظ ان العديد من القيم عندما يكون العميل مفقود تكون سالب لذالك سوف نسقطها لاننا نريد تصنيف العميل
# Out:
#        Invoice StockCode                Description  Quantity  \
# 263     489464     21733               85123a mixed       -96
# 283     489463     71477                      short      -240
# 284     489467    85123A                21733 mixed      -192
# 470     489521     21646                        NaN       -50
# 577     489525    85226C  BLUE PULL BACK RACING CAR         1
# ...        ...       ...                        ...       ...
# 525231  538159     21324                        NaN       -18
# 525232  538158     20892                        NaN       -32
# 525233  538160     20956                        NaN       288
# 525234  538161    46000S               Dotcom sales      -100
# 525235  538162    46000M               Dotcom sales      -100
#
#                InvoiceDate  Price  Customer ID         Country
# 263    2009-12-01 10:52:00   0.00          NaN  United Kingdom
# 283    2009-12-01 10:52:00   0.00          NaN  United Kingdom
# ...

# %%
df[df['Price'] <0 ]
# Out:
#         Invoice StockCode      Description  Quantity         InvoiceDate  \
# 179403  A506401         B  Adjust bad debt         1 2010-04-29 13:36:00
# 276274  A516228         B  Adjust bad debt         1 2010-07-19 11:24:00
# 403472  A528059         B  Adjust bad debt         1 2010-10-20 12:04:00
#
#            Price  Customer ID         Country
# 179403 -53594.36          NaN  United Kingdom
# 276274 -44031.79          NaN  United Kingdom
# 403472 -38925.87          NaN  United Kingdom

# %%
df[df['Quantity'] <0 ]
#  وهو يعني الغاء الفاتوره C اغلب القيم السالبه تحتوي الفاتوره على حرف
# Out:
#         Invoice StockCode                    Description  Quantity  \
# 178     C489449     22087       PAPER BUNTING WHITE LACE       -12
# 179     C489449    85206A   CREAM FELT EASTER EGG BASKET        -6
# 180     C489449     21895  POTTING SHED SOW 'N' GROW SET        -4
# 181     C489449     21896             POTTING SHED TWINE        -6
# 182     C489449     22083     PAPER CHAIN KIT RETRO SPOT       -12
# ...         ...       ...                            ...       ...
# 525231   538159     21324                            NaN       -18
# 525232   538158     20892                            NaN       -32
# 525234   538161    46000S                   Dotcom sales      -100
# 525235   538162    46000M                   Dotcom sales      -100
# 525282  C538164    35004B    SET OF 3 BLACK FLYING DUCKS        -1
#
#                InvoiceDate  Price  Customer ID         Country
# 178    2009-12-01 10:33:00   2.95      16321.0       Australia
# ...

# %%
df['Invoice'] = df['Invoice'].astype('str')
df[df['Invoice'].str.match('^\\d{6}$') == False]
# df[df['Invoice'].str.startswith('C')]
# Out:
#         Invoice StockCode                       Description  Quantity  \
# 178     C489449     22087          PAPER BUNTING WHITE LACE       -12
# 179     C489449    85206A      CREAM FELT EASTER EGG BASKET        -6
# 180     C489449     21895     POTTING SHED SOW 'N' GROW SET        -4
# 181     C489449     21896                POTTING SHED TWINE        -6
# 182     C489449     22083        PAPER CHAIN KIT RETRO SPOT       -12
# ...         ...       ...                               ...       ...
# 524695  C538123     22956          36 FOIL HEART CAKE CASES        -2
# 524696  C538124         M                            Manual        -4
# 524697  C538124     22699  ROSES REGENCY TEACUP AND SAUCER         -1
# 524698  C538124     22423          REGENCY CAKESTAND 3 TIER        -1
# 525282  C538164    35004B       SET OF 3 BLACK FLYING DUCKS        -1
#
#                InvoiceDate  Price  Customer ID         Country
# 178    2009-12-01 10:33:00   2.95      16321.0       Australia
# ...

# %%
df['Invoice'].str.replace("[0-9]", "", regex=True).unique()
# الخيار regex=True يعني أن النص الموجود بين الأقواس "[0-9]" هو تعبير نمطي (Regular Expression)، وليس نصًا عاديًا فقط.
# A, C  نلاحظ ان الفواتير الملغيه تحتوي على الاحرف
# Out:
# array(['', 'C', 'A'], dtype=object)

# %%
df[df['Invoice'].str.startswith('A')]
#  ثلاث اعمد سوف نقوم بحذفها
# Out:
#         Invoice StockCode      Description  Quantity         InvoiceDate  \
# 179403  A506401         B  Adjust bad debt         1 2010-04-29 13:36:00
# 276274  A516228         B  Adjust bad debt         1 2010-07-19 11:24:00
# 403472  A528059         B  Adjust bad debt         1 2010-10-20 12:04:00
#
#            Price  Customer ID         Country
# 179403 -53594.36          NaN  United Kingdom
# 276274 -44031.79          NaN  United Kingdom
# 403472 -38925.87          NaN  United Kingdom

# %%
# في الموقع تحدث عن هذا العامود لذالك سوف نتاكد منه
# StockCode: Product (item) code. Nominal. A 5-digit integral number uniquely assigned to each distinct product.
df["StockCode"] = df["StockCode"].astype("str")
df[(df['StockCode'].str.match('^\\d{5}$') == False) & (df['StockCode'].str.match('^\\d{5}[a-zA-Z]+$') == False)]['StockCode'].unique()
# Out:
# array(['POST', 'D', 'DCGS0058', 'DCGS0068', 'DOT', 'M', 'DCGS0004',
#        'DCGS0076', 'C2', 'BANK CHARGES', 'DCGS0003', 'TEST001',
#        'gift_0001_80', 'DCGS0072', 'gift_0001_20', 'DCGS0044', 'TEST002',
#        'gift_0001_10', 'gift_0001_50', 'DCGS0066N', 'gift_0001_30',
#        'PADS', 'ADJUST', 'gift_0001_40', 'gift_0001_60', 'gift_0001_70',
#        'gift_0001_90', 'DCGSSGIRL', 'DCGS0006', 'DCGS0016', 'DCGS0027',
#        'DCGS0036', 'DCGS0039', 'DCGS0060', 'DCGS0056', 'DCGS0059', 'GIFT',
#        'DCGSLBOY', 'm', 'DCGS0053', 'DCGS0062', 'DCGS0037', 'DCGSSBOY',
#        'DCGSLGIRL', 'S', 'DCGS0069', 'DCGS0070', 'DCGS0075', 'B',
#        'DCGS0041', 'ADJUST2', '47503J ', 'C3', 'SP1002', 'AMAZONFEE'],
#       dtype=object)

# %%
df[df['StockCode'].str.contains("DCG")]
#  يجب ان يتم استبعاده لانه العميل فارغ وبعض الكميه سالبه
# Out:
#        Invoice  StockCode                       Description  Quantity  \
# 2377    489597   DCGS0058                  MISO PRETTY  GUM         1
# 2378    489597   DCGS0068                 DOGS NIGHT COLLAR         1
# 8371    490074   DCGS0004        HAYNES CAMPER SHOULDER BAG         1
# 8372    490074   DCGS0058                  MISO PRETTY  GUM         1
# 8373    490074   DCGS0076      SUNJAR LED NIGHT NIGHT LIGHT         1
# 16426   490741   DCGS0076      SUNJAR LED NIGHT NIGHT LIGHT         1
# 17264   490745   DCGS0058                  MISO PRETTY  GUM         1
# 17265   490745   DCGS0076      SUNJAR LED NIGHT NIGHT LIGHT         1
# 20249   491041   DCGS0003               BOXED GLASS ASHTRAY         1
# 20324   491043   DCGS0076      SUNJAR LED NIGHT NIGHT LIGHT         1
# 30671   491969   DCGS0058                  MISO PRETTY  GUM         1
# 30672   491969   DCGS0072            CAT CAMOUFLAGUE COLLAR         1
# ...

# %%
df[df['StockCode'].str.contains("^D")]
#  يجب ان يتم استبعاده
# Out:
#         Invoice StockCode        Description  Quantity         InvoiceDate  \
# 735     C489535         D           Discount        -1 2009-12-01 12:11:00
# 736     C489535         D           Discount        -1 2009-12-01 12:11:00
# 2377     489597  DCGS0058   MISO PRETTY  GUM         1 2009-12-01 14:28:00
# 2378     489597  DCGS0068  DOGS NIGHT COLLAR         1 2009-12-01 14:28:00
# 2379     489597       DOT     DOTCOM POSTAGE         1 2009-12-01 14:28:00
# ...         ...       ...                ...       ...                 ...
# 524272   538071       DOT     DOTCOM POSTAGE         1 2010-12-09 14:09:00
# 524887   538148       DOT     DOTCOM POSTAGE         1 2010-12-09 16:26:00
# 525000   538149       DOT     DOTCOM POSTAGE         1 2010-12-09 16:27:00
# 525126   538153       DOT     DOTCOM POSTAGE         1 2010-12-09 16:31:00
# 525147   538154       DOT     DOTCOM POSTAGE         1 2010-12-09 16:35:00
#
#          Price  Customer ID         Country
# ...

# %%
df[df['StockCode'].str.contains("^PADS")]
# Out:
#         Invoice StockCode                 Description  Quantity  \
# 62299    494914      PADS  PADS TO MATCH ALL CUSHIONS         1
# 74731    496222      PADS  PADS TO MATCH ALL CUSHIONS         1
# 77702    496473      PADS  PADS TO MATCH ALL CUSHIONS         1
# 79794    496643      PADS  PADS TO MATCH ALL CUSHIONS         1
# 90798    497935      PADS  PADS TO MATCH ALL CUSHIONS         1
# 97716    498562      PADS  PADS TO MATCH ALL CUSHIONS         1
# 101718   499056      PADS  PADS TO MATCH ALL CUSHIONS         1
# 104480   499399      PADS  PADS TO MATCH ALL CUSHIONS         1
# 123947   501176      PADS  PADS TO MATCH ALL CUSHIONS         1
# 156809   504332      PADS  PADS TO MATCH ALL CUSHIONS         1
# 178629   506303      PADS  PADS TO MATCH ALL CUSHIONS         1
# 249035  C513477      PADS  PADS TO MATCH ALL CUSHIONS        -1
# 341826   522766      PADS  PADS TO MATCH ALL CUSHIONS         1
# 440930   531433      PADS  PADS TO MATCH ALL CUSHIONS         1
# ...

# %%
df[df['StockCode'].str.contains("^POST")]
# Out:
#         Invoice StockCode Description  Quantity         InvoiceDate   Price  \
# 89       489439      POST     POSTAGE         3 2009-12-01 09:28:00   18.00
# 126      489444      POST     POSTAGE         1 2009-12-01 09:55:00  141.00
# 173      489447      POST     POSTAGE         1 2009-12-01 10:10:00  130.00
# 625      489526      POST     POSTAGE         6 2009-12-01 11:50:00   18.00
# 927     C489538      POST     POSTAGE        -1 2009-12-01 12:18:00    9.58
# ...         ...       ...         ...       ...                 ...     ...
# 522916   537967      POST     POSTAGE         1 2010-12-09 11:31:00   18.00
# 522930   537995      POST     POSTAGE         2 2010-12-09 11:39:00   18.00
# 522974   538003      POST     POSTAGE         8 2010-12-09 12:05:00   18.00
# 523064   538008      POST     POSTAGE         5 2010-12-09 12:17:00   18.00
# 524491   538093      POST     POSTAGE         5 2010-12-09 14:49:00   18.00
#
#         Customer ID         Country
# ...

# %%
df[df['StockCode'].str.contains("^DOT")]
#  يجب ان يتم استبعاده
# Out:
#        Invoice StockCode     Description  Quantity         InvoiceDate  \
# 2379    489597       DOT  DOTCOM POSTAGE         1 2009-12-01 14:28:00
# 2539    489600       DOT  DOTCOM POSTAGE         1 2009-12-01 14:43:00
# 2551    489601       DOT  DOTCOM POSTAGE         1 2009-12-01 14:44:00
# 2571    489602       DOT  DOTCOM POSTAGE         1 2009-12-01 14:45:00
# 2619    489603       DOT  DOTCOM POSTAGE         1 2009-12-01 14:46:00
# ...        ...       ...             ...       ...                 ...
# 524272  538071       DOT  DOTCOM POSTAGE         1 2010-12-09 14:09:00
# 524887  538148       DOT  DOTCOM POSTAGE         1 2010-12-09 16:26:00
# 525000  538149       DOT  DOTCOM POSTAGE         1 2010-12-09 16:27:00
# 525126  538153       DOT  DOTCOM POSTAGE         1 2010-12-09 16:31:00
# 525147  538154       DOT  DOTCOM POSTAGE         1 2010-12-09 16:35:00
#
#          Price  Customer ID         Country
# 2379    647.19          NaN  United Kingdom
# ...

# %%
df[df['StockCode'].str.contains("^m")]
#  يجب ان يتم استبعاده
# Out:
#        Invoice StockCode Description  Quantity         InvoiceDate  Price  \
# 96608   498492         m      Manual         1 2010-02-19 10:56:00   2.55
# 96609   498492         m      Manual         1 2010-02-19 10:56:00   3.40
# 157226  504396         m      Manual         1 2010-04-13 11:45:00   4.00
# 228780  511509         m      Manual         1 2010-06-08 15:26:00   2.55
#
#         Customer ID         Country
# 96608           NaN  United Kingdom
# 96609           NaN  United Kingdom
# 157226          NaN  United Kingdom
# 228780          NaN  United Kingdom

# %%
df[df['StockCode'].str.contains("^M")]
#  يجب ان يتم استبعاده
# Out:
#         Invoice StockCode Description  Quantity         InvoiceDate    Price  \
# 2697     489609         M      Manual         1 2009-12-01 14:50:00     4.00
# 3053    C489651         M      Manual        -1 2009-12-01 16:48:00     5.10
# 5897    C489859         M      Manual        -1 2009-12-02 14:45:00    69.57
# 9259    C490126         M      Manual        -1 2009-12-03 18:12:00     5.95
# 9307    C490129         M      Manual        -1 2009-12-03 18:26:00  1998.49
# ...         ...       ...         ...       ...                 ...      ...
# 521074   537800         M      Manual        12 2010-12-08 13:08:00     0.19
# 521122   537804         M      Manual        12 2010-12-08 13:17:00     2.95
# 521124   537804         M      Manual        12 2010-12-08 13:17:00     0.19
# 524696  C538124         M      Manual        -4 2010-12-09 15:43:00     0.50
# 524776   538147         M      Manual         1 2010-12-09 16:11:00    15.00
#
#         Customer ID         Country
# ...

# %%
df[df['StockCode'].str.contains("^C2")]
#  يجب ان يتم استبعاده
# Out:
#         Invoice StockCode Description  Quantity         InvoiceDate  Price  \
# 9292     490127        C2    CARRIAGE         1 2009-12-03 18:13:00   50.0
# 14481    490541        C2    CARRIAGE         1 2009-12-07 09:25:00   50.0
# 14502    490542        C2    CARRIAGE         1 2009-12-07 09:42:00   50.0
# 19541    490998        C2    CARRIAGE         1 2009-12-08 17:24:00   50.0
# 22803    491160        C2    CARRIAGE         1 2009-12-10 10:29:00   50.0
# 27494    491702        C2    CARRIAGE         1 2009-12-13 13:53:00   50.0
# 32207    491990        C2         NaN       100 2009-12-15 10:06:00    0.0
# 32964    492092        C2    CARRIAGE         1 2009-12-15 14:03:00   50.0
# 34330    492250        C2    CARRIAGE         1 2009-12-16 10:45:00   50.0
# 39877    492746        C2    CARRIAGE         1 2009-12-18 13:01:00   50.0
# 44683    493308        C2    CARRIAGE         1 2009-12-22 16:17:00   50.0
# ...

# %%
df[df['StockCode'].str.contains("^C3")]
#  يجب ان يتم استبعاده
# Out:
#        Invoice StockCode Description  Quantity         InvoiceDate  Price  \
# 302041  518785        C3         NaN     -4999 2010-08-11 16:55:00    0.0
#
#         Customer ID         Country
# 302041          NaN  United Kingdom

# %%
df[df['StockCode'].str.contains("^B")]
#  يجب ان يتم استبعاده
# Out:
#         Invoice     StockCode      Description  Quantity         InvoiceDate  \
# 18410   C490943  BANK CHARGES     Bank Charges        -1 2009-12-08 14:08:00
# 18466    490948  BANK CHARGES     Bank Charges         1 2009-12-08 14:29:00
# 33435   C492206  BANK CHARGES     Bank Charges        -1 2009-12-15 16:32:00
# 55948   C494438  BANK CHARGES     Bank Charges        -1 2010-01-14 12:15:00
# 94431    498269  BANK CHARGES     Bank Charges         1 2010-02-17 15:03:00
# 104220  C499374  BANK CHARGES     Bank Charges        -1 2010-02-26 11:55:00
# 114180  C500319  BANK CHARGES     Bank Charges       -11 2010-03-07 12:02:00
# 115208  C500352  BANK CHARGES     Bank Charges        -1 2010-03-07 15:08:00
# 118558  C500708  BANK CHARGES     Bank Charges        -1 2010-03-09 13:56:00
# 136411  C502459  BANK CHARGES     Bank Charges        -1 2010-03-24 14:25:00
# 143558  C503050  BANK CHARGES     Bank Charges        -1 2010-03-29 15:38:00
# ...

# %%
df[df['StockCode'].str.contains("^S")]
#  يجب ان يتم استبعاده
# Out:
#         Invoice StockCode             Description  Quantity  \
# 114061  C500305         S                 SAMPLES        -1
# 114083  C500309         S                 SAMPLES        -1
# 133558  C502083         S                 SAMPLES        -1
# 133582  C502088         S                 SAMPLES        -1
# 136253  C502438         S                 SAMPLES        -1
# 136259  C502442         S                 SAMPLES        -1
# 181508   506601         S                 SAMPLES         1
# 181509  C506602         S                 SAMPLES        -1
# 181510  C506602         S                 SAMPLES        -1
# 181511  C506602         S                 SAMPLES        -1
# 181512  C506602         S                 SAMPLES        -1
# 181513  C506602         S                 SAMPLES        -1
# 181540  C506605         S                 SAMPLES        -1
# 181543  C506607         S                 SAMPLES        -1
# 181544  C506607         S                 SAMPLES        -1
# ...

# %%
df[df['StockCode'].str.contains("^TES")]
#  يجب ان يتم استبعاده
# Out:
#         Invoice StockCode              Description  Quantity  \
# 27994    491725   TEST001  This is a test product.        10
# 28251    491742   TEST001  This is a test product.         5
# 28254    491744   TEST001  This is a test product.         5
# 39398    492718   TEST001  This is a test product.         5
# 39411    492722   TEST002  This is a test product.         1
# 44614    493294   TEST002                      NaN         1
# 45228    493410   TEST001  This is a test product.         5
# 45230    493412   TEST001  This is a test product.         5
# 56117    494450   TEST001  This is a test product.         5
# 66084    495295   TEST001  This is a test product.         5
# 89084    497819   TEST001  This is a test product.         5
# 89180    497843   TEST001  This is a test product.         5
# 156017   504188   TEST001  This is a test product.         5
# 371777  C525272   TEST001  This is a test product.        -1
# ...

# %%
df[df['StockCode'].str.contains("^gift")]
#  يجب ان يتم استبعاده
# Out:
#         Invoice     StockCode                         Description  Quantity  \
# 30620    491968  gift_0001_80                                 NaN         2
# 31079    491969  gift_0001_80  Dotcomgiftshop Gift Voucher £80.00         1
# 32048    491971  gift_0001_20  Dotcomgiftshop Gift Voucher £20.00         2
# 40904    492782  gift_0001_10  Dotcomgiftshop Gift Voucher £10.00         1
# 40905    492782  gift_0001_20  Dotcomgiftshop Gift Voucher £20.00         1
# 41263    492783  gift_0001_50  Dotcomgiftshop Gift Voucher £50.00         1
# 45212    493404  gift_0001_30  Dotcomgiftshop Gift Voucher £30.00         1
# 45213    493404  gift_0001_20  Dotcomgiftshop Gift Voucher £20.00         1
# 54564    494380  gift_0001_30                                 NaN         5
# 54636    494381  gift_0001_30  Dotcomgiftshop Gift Voucher £30.00         1
# 56446   C494472  gift_0001_80  Dotcomgiftshop Gift Voucher £80.00        -1
# ...

# %%
df[df['StockCode'].str.contains("^SP1002")]
#  يجب ان يتم استبعاده
# Out:
#        Invoice StockCode             Description  Quantity  \
# 377066  525772    SP1002  KID'S CHALKBOARD/EASEL         1
# 377387  525837    SP1002  KID'S CHALKBOARD/EASEL         4
# 426694  530135    SP1002                     NaN       -27
#
#                InvoiceDate  Price  Customer ID         Country
# 377066 2010-10-07 11:12:00   2.95      12748.0  United Kingdom
# 377387 2010-10-07 12:23:00   2.95      17841.0  United Kingdom
# 426694 2010-11-01 15:33:00   0.00          NaN  United Kingdom

# %%
df[df['StockCode'].str.contains("^AMAZONFEE")]
#  يجب ان يتم استبعاده
# Out:
#         Invoice  StockCode Description  Quantity         InvoiceDate  \
# 440688  C531400  AMAZONFEE  AMAZON FEE        -1 2010-11-08 10:08:00
# 440698   531411  AMAZONFEE  AMAZON FEE         1 2010-11-08 10:11:00
# 517452  C537600  AMAZONFEE  AMAZON FEE        -1 2010-12-07 12:41:00
# 517953  C537630  AMAZONFEE  AMAZON FEE        -1 2010-12-07 15:04:00
# 517955   537632  AMAZONFEE  AMAZON FEE         1 2010-12-07 15:08:00
# 519170  C537644  AMAZONFEE  AMAZON FEE        -1 2010-12-07 15:34:00
# 519251  C537647  AMAZONFEE  AMAZON FEE        -1 2010-12-07 15:41:00
# 519294  C537651  AMAZONFEE  AMAZON FEE        -1 2010-12-07 15:49:00
# 519295  C537652  AMAZONFEE  AMAZON FEE        -1 2010-12-07 15:51:00
#
#            Price  Customer ID         Country
# 440688   6706.71          NaN  United Kingdom
# 440698   6706.71          NaN  United Kingdom
# 517452      1.00          NaN  United Kingdom
# 517953  13541.33          NaN  United Kingdom
# ...

# %%
df[df['StockCode'].str.contains("^ADJUST")]
#  يجب ان يتم استبعاده
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 70975    495732    ADJUST  Adjustment by john on 26/01/2010 16         1
# 70976    495733    ADJUST  Adjustment by john on 26/01/2010 16         1
# 70977    495735    ADJUST  Adjustment by john on 26/01/2010 16         1
# 70978    495734    ADJUST  Adjustment by john on 26/01/2010 16         1
# 70979   C495737    ADJUST  Adjustment by john on 26/01/2010 16        -1
# 70980    495736    ADJUST  Adjustment by john on 26/01/2010 16         1
# 70981   C495740    ADJUST  Adjustment by john on 26/01/2010 16        -1
# 70982   C495738    ADJUST  Adjustment by john on 26/01/2010 16        -1
# 70983   C495739    ADJUST  Adjustment by john on 26/01/2010 16        -1
# 70984   C495744    ADJUST  Adjustment by john on 26/01/2010 16        -1
# 70985    495742    ADJUST  Adjustment by john on 26/01/2010 16         1
# 70986   C495741    ADJUST  Adjustment by john on 26/01/2010 16        -1
# ...

# %%
df[df['StockCode'].str.contains("^GIFT")]
#  يجب ان يتم استبعاده
# Out:
#       Invoice StockCode Description  Quantity         InvoiceDate  Price  \
# 83304  497107      GIFT         NaN        -9 2010-02-05 15:18:00    0.0
#
#        Customer ID         Country
# 83304          NaN  United Kingdom

# %%
df[df['StockCode'].str.contains("^47503J")]
#  يجب ان يتم استبعاده
# Out:
#         Invoice StockCode                       Description  Quantity  \
# 2981     489642    47503J  SET/3 FLORAL GARDEN TOOLS IN BAG         1
# 9784     490149    47503J  SET/3 FLORAL GARDEN TOOLS IN BAG         1
# 15894    490711    47503J  SET/3 FLORAL GARDEN TOOLS IN BAG         1
# 20061    491041    47503J  SET/3 FLORAL GARDEN TOOLS IN BAG         1
# 24867   C491446    47503J  SET/3 FLORAL GARDEN TOOLS IN BAG        -7
# 27489    491702    47503J  SET/3 FLORAL GARDEN TOOLS IN BAG         6
# 28428    491758    47503J  SET/3 FLORAL GARDEN TOOLS IN BAG         1
# 28557    491782    47503J  SET/3 FLORAL GARDEN TOOLS IN BAG         1
# 35130    492319    47503J  SET/3 FLORAL GARDEN TOOLS IN BAG         1
# 42859    493073    47503J  SET/3 FLORAL GARDEN TOOLS IN BAG         1
# 43385    493079    47503J  SET/3 FLORAL GARDEN TOOLS IN BAG         1
# 46697    493709    47503J  SET/3 FLORAL GARDEN TOOLS IN BAG        24
# ...

# %%
df.Country.value_counts()
# Out:
# Country
# United Kingdom          485852
# EIRE                      9670
# Germany                   8129
# France                    5772
# Netherlands               2769
# Spain                     1278
# Switzerland               1187
# Portugal                  1101
# Belgium                   1054
# Channel Islands            906
# Sweden                     902
# Italy                      731
# Australia                  654
# Cyprus                     554
# Austria                    537
# Greece                     517
# United Arab Emirates       432
# Denmark                    428
# Norway                     369
# Finland                    354
# Unspecified                310
# USA                        244
# Japan                      224
# Poland                     194
# Malta                      172
# Lithuania                  154
# Singapore                  117
# RSA                        111
# Bahrain                    107
# Canada                      77
# ...

# %%
df.Description.value_counts()
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER     3549
# REGENCY CAKESTAND 3 TIER               2212
# STRAWBERRY CERAMIC TRINKET BOX         1843
# PACK OF 72 RETRO SPOT CAKE CASES       1466
# ASSORTED COLOUR BIRD ORNAMENT          1457
#                                        ...
# stock credited from royal yacht inc       1
# VINTAGE METAL CAKE STAND CREAM            1
# BLUE BAROQUE FLOCK CANDLE HOLDER          1
# S/4 HEART CRYSTAL FRIDGE MAGNETS          1
# dotcom email                              1
# Name: count, Length: 4681, dtype: int64

# %%
sns.histplot(data = df.sample(40000), x='Quantity')
# Out:
# <Axes: xlabel='Quantity', ylabel='Count'>

# %%
sns.histplot(data = df.sample(40000), x='Price')
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.histplot(data = df.sample(40000), x='Customer ID')
# Out:
# <Axes: xlabel='Customer ID', ylabel='Count'>

# %% [markdown]
# # Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  int64
#  4   InvoiceDate  525461 non-null  datetime64[ns]
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  float64
#  7   Country      525461 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 32.1+ MB

# %%
cleaned_df = df.copy()

# %%
#   حذف الفواتير الملغاه
cleaned_df['Invoice'] = cleaned_df['Invoice'].astype("str")
mask = (
    cleaned_df['Invoice'].str.match("^\\d{6}$") == True
)
cleaned_df = cleaned_df[mask]
cleaned_df
# cleaned_df = cleaned_df[cleaned_df['Invoice'].str.match("^\\d{6}$") == True]
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %%
cleaned_df['StockCode'] = cleaned_df['StockCode'].astype("str")
cleaned_df = cleaned_df[(cleaned_df['StockCode'].str.contains("PADS"))|(cleaned_df['StockCode'].str.match('^\\d{5}$') == True) | (cleaned_df['StockCode'].str.match('^\\d{5}[a-zA-Z]+$') == True)]
cleaned_df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %%
cleaned_df.dropna(subset=['Customer ID'], inplace=True)
# Out:
# C:\Users\aa\AppData\Local\Temp\ipykernel_6480\376660035.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df.dropna(subset=['Customer ID'], inplace=True)

# %%
cleaned_df.describe()
# Out:
#             Quantity                    InvoiceDate          Price  \
# count  406337.000000                         406337  406337.000000
# mean       13.619099  2010-07-01 10:11:06.543288320       2.991462
# min         1.000000            2009-12-01 07:45:00       0.000000
# 25%         2.000000            2010-03-26 14:01:00       1.250000
# 50%         5.000000            2010-07-09 15:48:00       1.950000
# 75%        12.000000            2010-10-14 17:09:00       3.750000
# max     19152.000000            2010-12-09 20:01:00     295.000000
# std        97.000659                            NaN       4.285876
#
#          Customer ID
# count  406337.000000
# mean    15373.632992
# min     12346.000000
# 25%     14004.000000
# 50%     15326.000000
# 75%     16814.000000
# max     18287.000000
# std      1677.365907

# %%
cleaned_df = cleaned_df[cleaned_df.Price > 0]

# %%
cleaned_df.describe()
# Out:
#             Quantity                    InvoiceDate          Price  \
# count  406309.000000                         406309  406309.000000
# mean       13.617924  2010-07-01 10:14:25.869572352       2.991668
# min         1.000000            2009-12-01 07:45:00       0.001000
# 25%         2.000000            2010-03-26 14:01:00       1.250000
# 50%         5.000000            2010-07-09 15:48:00       1.950000
# 75%        12.000000            2010-10-14 17:09:00       3.750000
# max     19152.000000            2010-12-09 20:01:00     295.000000
# std        96.998833                            NaN       4.285951
#
#          Customer ID
# count  406309.000000
# mean    15373.722268
# min     12346.000000
# 25%     14006.000000
# 50%     15326.000000
# 75%     16814.000000
# max     18287.000000
# std      1677.329470

# %%
len(cleaned_df)/len(df)
# Dropped about 23% records
# Out:
# 0.7732429238325965

# %% [markdown]
# # Feature Engineering

# %%
cleaned_df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %%
#  بما ان السعر هو لقطعه واحده يجب حساب السعر لكامل العمليه
cleaned_df["SalesLineTotal"] = cleaned_df["Price"] * cleaned_df["Quantity"]
cleaned_df
# Out:
# C:\Users\aa\AppData\Local\Temp\ipykernel_6480\2134793649.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df["SalesLineTotal"] = cleaned_df["Price"] * cleaned_df["Quantity"]
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# ...

# %%
#as_index=False تعني أنك لا تريد أن يكون عمود التجميع (مثلاً "Customer ID") هو الفهرس (index) في الناتج النهائي، بل تريده كعمود عادي في DataFrame.
aggregated_df = cleaned_df.groupby(by='Customer ID', as_index=False) \
    .agg(
        # cleaned_df.groupby(by='Customer ID', as_index=False)['SalesLineTotal'].sum()
        MonetaryValue=("SalesLineTotal","sum"),
        
        # cleaned_df.groupby('Customer ID')['Invoice'].nunique().reset_index(name='Frequency')
        Frequency=("Invoice", "nunique"),

        # aggregated_df = df.groupby('Customer ID')['InvoiceDate'].max().reset_index(name='LastInvoiceDate')

        # اخر فاتوره لكل عميل
        LastInvoiceDate=("InvoiceDate", "max")
    )
aggregated_df
# Out:
#       Customer ID  MonetaryValue  Frequency     LastInvoiceDate
# 0         12346.0         169.36          2 2010-06-28 13:53:00
# 1         12347.0        1323.32          2 2010-12-07 14:57:00
# 2         12348.0         221.16          1 2010-09-27 14:59:00
# 3         12349.0        2221.14          2 2010-10-28 08:23:00
# 4         12351.0         300.93          1 2010-11-29 15:23:00
# ...           ...            ...        ...                 ...
# 4280      18283.0         641.77          6 2010-11-22 15:30:00
# 4281      18284.0         411.68          1 2010-10-04 11:33:00
# 4282      18285.0         377.00          1 2010-02-17 10:24:00
# 4283      18286.0        1246.43          2 2010-08-20 11:57:00
# 4284      18287.0        2295.71          4 2010-11-22 11:51:00
#
# [4285 rows x 4 columns]

# %%
#  بحساب مدى "حداثة"  آخر فاتورة لكل عميل Recency بناءً على آخر تاريخ فاتورة موجود في البيانات
#  يستخدم في تحليل العملاء لمعرفة مدى نشاط العميل من حيث الوقت منذ آخر تعامل معه
max_invoice_date = aggregated_df["LastInvoiceDate"].max()
aggregated_df["Recency"] = (max_invoice_date - aggregated_df["LastInvoiceDate"]).dt.days
aggregated_df
# Out:
#       Customer ID  MonetaryValue  Frequency     LastInvoiceDate  Recency
# 0         12346.0         169.36          2 2010-06-28 13:53:00      164
# 1         12347.0        1323.32          2 2010-12-07 14:57:00        2
# 2         12348.0         221.16          1 2010-09-27 14:59:00       73
# 3         12349.0        2221.14          2 2010-10-28 08:23:00       42
# 4         12351.0         300.93          1 2010-11-29 15:23:00       10
# ...           ...            ...        ...                 ...      ...
# 4280      18283.0         641.77          6 2010-11-22 15:30:00       17
# 4281      18284.0         411.68          1 2010-10-04 11:33:00       66
# 4282      18285.0         377.00          1 2010-02-17 10:24:00      295
# 4283      18286.0        1246.43          2 2010-08-20 11:57:00      111
# 4284      18287.0        2295.71          4 2010-11-22 11:51:00       17
#
# [4285 rows x 5 columns]

# %%
plt.figure(figsize=(15, 8))
#  نلاحظ من خلال الرسم انه يوجد قيم منحرفه
plt.subplot(1, 3, 1)
plt.hist(aggregated_df["MonetaryValue"], bins=10, color='skyblue', edgecolor='black')
plt.title("Monetary Value Distribution")
plt.xlabel("Monetary Value")
plt.xticks(rotation=60)
plt.ylabel("Count")

#  نلاحظ من خلال الرسم انه يوجد قيم منحرفه
plt.subplot(1, 3, 2)
plt.hist(aggregated_df["Frequency"], bins=10, color='lightgreen', edgecolor='black')
plt.title("Frequency Distribution")
plt.xlabel("Frequency")
plt.ylabel("Count")

#  نلاحظ من خلال الرسم انه  لا يوجد قيم منحرفه وهي طبيعيه
plt.subplot(1, 3, 3)
plt.hist(aggregated_df["Recency"], bins=20, color='salmon', edgecolor='black')
plt.title("Recency Distribution")
plt.xlabel("Recency")
plt.ylabel("Count")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 8))

# يوجد قيم متطرفه
plt.subplot(3, 1, 1)
sns.boxplot(data=aggregated_df, x= "MonetaryValue", color='skyblue')
plt.title("Monetary Value Outliers")
plt.xlabel("Monetary Value")
plt.xticks(rotation=60)
plt.ylabel("Count")

# يوجد قيم متطرفه
plt.subplot(3, 1, 2)
sns.boxplot(data=aggregated_df, x= "Frequency", color='lightgreen')
plt.title("Frequency Outliers")
plt.xlabel("Frequency")
plt.ylabel("Count")

# يوجد قيم لا باس بها من القيم المتطرفه
plt.subplot(3, 1, 3)
sns.boxplot(data=aggregated_df, x= "Recency", color='salmon')
plt.title("Recency Outliers")
plt.xlabel("Recency")
plt.ylabel("Count")

plt.tight_layout()
plt.show()


#  يمكن ازاله القيم المتطرفه ولكن القيم قد تكون مهمه
#  ونحن لا نريد حذف العملاء الذين يدفعون كثيرا لانهم الاهم
#  لذالك سوف نقوم بفصلها ونعمل عليها دراسه خاص

# %%
# IQR في كشف القيم المتطرفة تُستخدم عادةً في التحليل غير المراقب بشكل أكبر
M_Q1 = aggregated_df["MonetaryValue"].quantile(0.25)
M_Q3 = aggregated_df["MonetaryValue"].quantile(0.75)
M_IQR = M_Q3 - M_Q1
monetary_outliers_df = aggregated_df[(aggregated_df["MonetaryValue"] > (M_Q3 + 1.5 * M_IQR)) | (aggregated_df["MonetaryValue"] < (M_Q1 - 1.5 * M_IQR))].copy()
monetary_outliers_df.describe()
# Out:
#         Customer ID  MonetaryValue   Frequency                LastInvoiceDate  \
# count    423.000000     423.000000  423.000000                            423
# mean   15103.040189   12188.101740   17.167849  2010-11-09 12:26:02.978723328
# min    12357.000000    3802.040000    1.000000            2009-12-10 18:03:00
# 25%    13622.000000    4605.940000    8.000000            2010-11-08 13:17:30
# 50%    14961.000000    6191.320000   12.000000            2010-11-26 12:19:00
# 75%    16692.000000   10273.235000   18.000000            2010-12-06 10:34:30
# max    18260.000000  349164.350000  183.000000            2010-12-09 19:32:00
# std     1728.661406   25830.851045   19.729755                            NaN
#
#           Recency
# count  423.000000
# mean    30.035461
# min      0.000000
# 25%      3.000000
# 50%     13.000000
# 75%     31.000000
# max    364.000000
# std     51.541004

# %%
# IQR في كشف القيم المتطرفة تُستخدم عادةً في التحليل غير المراقب بشكل أكبر
F_Q1 = aggregated_df["Frequency"].quantile(0.25)
F_Q3 = aggregated_df["Frequency"].quantile(0.75)
F_IQR = F_Q3 - F_Q1
frequency_outliers_df = aggregated_df[(aggregated_df["Frequency"] > (F_Q3 + 1.5 * F_IQR)) | (aggregated_df["Frequency"] < (F_Q1 - 1.5 * F_IQR))].copy()
frequency_outliers_df.describe()
# Out:
#         Customer ID  MonetaryValue   Frequency                LastInvoiceDate  \
# count    279.000000     279.000000  279.000000                            279
# mean   15352.655914   14409.714932   23.810036  2010-11-23 11:06:20.645161216
# min    12437.000000    1094.390000   12.000000            2010-05-12 16:51:00
# 25%    13800.000000    4331.560500   13.000000            2010-11-20 13:14:30
# 50%    15465.000000    6615.770000   17.000000            2010-12-02 10:46:00
# 75%    16828.500000   11692.405000   23.000000            2010-12-07 11:08:30
# max    18260.000000  349164.350000  183.000000            2010-12-09 19:32:00
# std     1748.429987   31381.736785   21.932937                            NaN
#
#           Recency
# count  279.000000
# mean    16.089606
# min      0.000000
# 25%      2.000000
# 50%      7.000000
# 75%     19.000000
# max    211.000000
# std     26.589117

# %%
non_outliers_df = aggregated_df[(~aggregated_df.index.isin(monetary_outliers_df.index))&(~aggregated_df.index.isin(frequency_outliers_df.index))]
non_outliers_df.describe()
# Out:
#         Customer ID  MonetaryValue    Frequency  \
# count   3809.000000    3809.000000  3809.000000
# mean   15376.482804     885.502197     2.863481
# min    12346.000000       1.550000     1.000000
# 25%    13912.000000     279.910000     1.000000
# 50%    15389.000000     588.050000     2.000000
# 75%    16854.000000    1269.050000     4.000000
# max    18287.000000    3788.210000    11.000000
# std     1693.199806     817.672283     2.243748
#
#                      LastInvoiceDate      Recency
# count                           3809  3809.000000
# mean   2010-09-03 11:16:46.516146176    97.082174
# min              2009-12-01 10:49:00     0.000000
# 25%              2010-07-08 14:48:00    22.000000
# 50%              2010-10-12 16:25:00    58.000000
# 75%              2010-11-17 13:14:00   154.000000
# max              2010-12-09 20:01:00   373.000000
# std                              NaN    98.111495

# %%
plt.figure(figsize=(15, 8))

# لا زال يوجد قيم متطرفه لكن افضل من قبل
plt.subplot(3, 1, 1)
sns.boxplot(data=non_outliers_df, x= "MonetaryValue", color='skyblue')
plt.title("Monetary Value Outliers")
plt.xlabel("Monetary Value")
plt.xticks(rotation=60)
plt.ylabel("Count")

# لا زال يوجد قيم متطرفه لكن افضل من قبل
plt.subplot(3, 1, 2)
sns.boxplot(data=non_outliers_df, x= "Frequency", color='lightgreen')
plt.title("Frequency Outliers")
plt.xlabel("Frequency")
plt.ylabel("Count")

# لا زال يوجد قيم متطرفه لكن افضل من قبل
plt.subplot(3, 1, 3)
sns.boxplot(data=non_outliers_df, x= "Recency", color='salmon')
plt.title("Recency Outliers")
plt.xlabel("Recency")
plt.ylabel("Count")

plt.tight_layout()
plt.show()

# %%
#  لتغيير القياسات scaling يجب تصغير القيم عن طريق استخدام 
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(projection="3d")
scatter = ax.scatter(non_outliers_df["MonetaryValue"], non_outliers_df["Frequency"], non_outliers_df["Recency"])
ax.set_xlabel("Monetary Value")
ax.set_ylabel("Frequency")
ax.set_zlabel("Recency")
ax.set_title("3D Scatter for Customer Data")
plt.show()

# %%
#  Scaling:
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data['MonetaryValue', 'Frequency', 'Recency'] = scaler.fit_transform(non_outliers_df[['MonetaryValue', 'Frequency', 'Recency']])
scaled_data
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[75], line 4
#       2 from sklearn.preprocessing import StandardScaler
#       3 scaler = StandardScaler()
# ----> 4 scaled_data['MonetaryValue', 'Frequency', 'Recency'] = scaler.fit_transform(non_outliers_df[['MonetaryValue', 'Frequency', 'Recency']])
#       5 scaled_data
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
scaled_data_df = pd.DataFrame(scaled_data, index=non_outliers_df.index, columns=('MonetaryValue', 'Frequency', 'Recency'))
scaled_data_df
# Out:
#       MonetaryValue  Frequency   Recency
# 0         -0.875945  -0.384889  0.682149
# 1          0.535514  -0.384889 -0.969251
# 2         -0.812586  -0.830631 -0.245489
# 3          1.633678  -0.384889 -0.561498
# 4         -0.715016  -0.830631 -0.887700
# ...             ...        ...       ...
# 3804      -0.298120   1.398076 -0.816344
# 3805      -0.579553  -0.830631 -0.316846
# 3806      -0.621972  -0.830631  2.017539
# 3807       0.441467  -0.384889  0.141876
# 3808       1.724888   0.506593 -0.816344
#
# [3809 rows x 3 columns]

# %%
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(projection="3d")
scatter = ax.scatter(scaled_data_df["MonetaryValue"], scaled_data_df["Frequency"], scaled_data_df["Recency"])
ax.set_xlabel("Monetary Value")
ax.set_ylabel("Frequency")
ax.set_zlabel("Recency")
ax.set_title("3D Scatter for Customer Data")
plt.show()

# %% [markdown]
# # KMeans Clustering

# %%
from sklearn.cluster import KMeans
from sklearn.metrics.cluster import silhouette_score
options = range(2, 20)
inertia = []
silhoute_score = []
for n_cluster in options:
    kmeans = KMeans(n_cluster, random_state=42, max_iter=1000)
    
    cluster_labels = kmeans.fit_predict(scaled_data_df) # kmeans.fit(scaled_data_df)
    sil_score = silhouette_score(scaled_data_df, cluster_labels)
    silhoute_score.append(sil_score)
    
    inertia.append(kmeans.inertia_)
    
df = pd.DataFrame({'No. of Clusters': list(options), 'Inertia': inertia, 'silhoute_scores':silhoute_score})

# %%
#  نلاحظ من خلال الرسم ان عدد الكلاستر تساوي 4 هو افضل شيء من خلال استخدام مقياسين للرسم
#  نختار الافضل من خلال الكوع الذي يحتوي على انخفاض في الانحدار 
plt.figure(figsize=(12, 7))
plt.subplot(1, 2, 1)
sns.lineplot(data=df, x='No. of Clusters', y='Inertia', marker='o')
plt.title("No. of clusters vs. Inertia")
plt.xlabel('No. of clusters (K)')
plt.ylabel('Inertia')
plt.xticks(options)
plt.grid()

plt.subplot(1, 2, 2)
sns.lineplot(data=df, x='No. of Clusters', y='silhoute_scores', marker='o')
plt.title("No. of clusters vs. silhoute_scores")
plt.xlabel('No. of clusters (K)')
plt.ylabel('silhoute_scores')
plt.xticks(options)
plt.grid()

plt.tight_layout()
plt.show()

# %%
kmeans = KMeans(n_clusters=4, random_state=42, max_iter=1000)
cluster_labels = kmeans.fit_predict(scaled_data_df)
cluster_labels
# Out:
# array([1, 0, 2, ..., 1, 0, 0])

# %%
kmeans.cluster_centers_
# Out:
# array([[ 0.51939359,  0.46749336, -0.48229465],
#        [-0.61275322, -0.63938694,  1.57069511],
#        [-0.57155341, -0.54227972, -0.43883252],
#        [ 1.89659538,  1.95209499, -0.64418351]])

# %%
sns.scatterplot(data=scaled_data_df, x='MonetaryValue', y='Recency', hue=cluster_labels);
centers_x, centers_y = kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,2]
plt.plot(centers_x, centers_y, 'xr')

# %%
scaled_data_df.columns
# Out:
# Index(['MonetaryValue', 'Frequency', 'Recency'], dtype='object')

# %%
def test_prams(**prams):
    kmeans = KMeans(random_state=42,  **prams).fit(scaled_data_df)
    preds = kmeans.predict(scaled_data_df)
    return silhouette_score(scaled_data_df, preds)

# %%
test_prams(n_clusters=4, max_iter=1000, verbose=0, tol=0.00001)
# Out:
# 0.4157270581180607

# %%
non_outliers_df['Cluster'] = cluster_labels
non_outliers_df
# Out:
# C:\Users\aa\AppData\Local\Temp\ipykernel_6480\395619450.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   non_outliers_df['Cluster'] = cluster_labels
#       Customer ID  MonetaryValue  Frequency     LastInvoiceDate  Recency  \
# 0         12346.0         169.36          2 2010-06-28 13:53:00      164
# 1         12347.0        1323.32          2 2010-12-07 14:57:00        2
# 2         12348.0         221.16          1 2010-09-27 14:59:00       73
# 3         12349.0        2221.14          2 2010-10-28 08:23:00       42
# 4         12351.0         300.93          1 2010-11-29 15:23:00       10
# ...           ...            ...        ...                 ...      ...
# ...

# %%
cluster_colors = {
    0:'#1f77b4',
    1:'#ff7f0e',
    2:'#2ca02c',
    3:'#d62728'
}
colors = non_outliers_df['Cluster'].map(cluster_colors)
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(projection="3d")
scatter = ax.scatter(non_outliers_df["MonetaryValue"], non_outliers_df["Frequency"], non_outliers_df["Recency"], c=colors)
ax.set_xlabel("Monetary Value")
ax.set_ylabel("Frequency")
ax.set_zlabel("Recency")
ax.set_title("3D Scatter for Customer Data")
plt.show()

# %% [markdown]
# - Cluster 0 : (Blue) -> Retain
# - Cluster 1 : (Orange) -> Re-Engage
# - Cluster 2 : (Green) -> Nurture
# - Cluster 3 : (Red) -> Reward
# - Retain, Re-Engage, Nurture, Reward
# - الاحتفاظ، إعادة المشاركة، الرعاية، المكافأة

# %% [markdown]
# # Use Outliers

# %%
#  يوجد قيم متداخله بحيث تكون متطرفه في الاولى والثانية
#  سوف نضع ثلاث مجموعات للاولى والثانية وللقيم المتداخلة
monetary_outliers_df
frequency_outliers_df
# Out:
#       Customer ID  MonetaryValue  Frequency     LastInvoiceDate  Recency
# 65        12437.0        6834.99         20 2010-11-09 14:46:00       30
# 84        12471.0       17721.45         44 2010-11-30 14:35:00        9
# 85        12472.0       10426.48         13 2010-12-05 14:19:00        4
# 92        12482.0       21941.72         27 2010-05-12 16:51:00      211
# 115       12523.0        2330.38         12 2010-11-30 12:31:00        9
# ...           ...            ...        ...                 ...      ...
# 4236      18225.0        7545.14         15 2010-12-09 15:46:00        0
# 4237      18226.0        6650.83         15 2010-11-26 15:51:00       13
# 4241      18231.0        4791.80         23 2010-10-29 14:17:00       41
# 4250      18245.0        3757.92         13 2010-11-25 16:52:00       14
# 4262      18260.0        7318.91         17 2010-11-30 12:25:00        9
#
# [279 rows x 5 columns]

# %%
overlap_indices = monetary_outliers_df.index.intersection(frequency_outliers_df.index)
overlap_indices
# Out:
# Index([  65,   84,   85,   92,  126,  145,  164,  179,  202,  203,
#        ...
#        4107, 4125, 4143, 4156, 4200, 4235, 4236, 4237, 4241, 4262],
#       dtype='int64', length=226)

# %%
monetary_only_outliers = monetary_outliers_df.drop(overlap_indices)
frequency_only_outliers = frequency_outliers_df.drop(overlap_indices)
monetary_frequency_outliers = frequency_outliers_df.loc[overlap_indices]

# نضع قيمه سالب لنقول اننا قمنا بتجميعه يدوي
monetary_only_outliers['Cluster'] = -1
frequency_only_outliers['Cluster'] = -2
monetary_frequency_outliers['Cluster'] = -3

outlier_clusters_df = pd.concat([monetary_only_outliers, frequency_only_outliers, monetary_frequency_outliers])
outlier_clusters_df
# Out:
#       Customer ID  MonetaryValue  Frequency     LastInvoiceDate  Recency  \
# 9         12357.0       11229.99          1 2010-11-16 10:05:00       23
# 25        12380.0        4782.84          4 2010-08-31 14:54:00      100
# 42        12409.0       12346.62          4 2010-10-15 10:24:00       55
# 48        12415.0       19468.84          4 2010-11-29 15:07:00       10
# 61        12431.0        4145.52         11 2010-12-01 10:03:00        8
# ...           ...            ...        ...                 ...      ...
# 4235      18223.0        7516.31         12 2010-11-17 12:20:00       22
# 4236      18225.0        7545.14         15 2010-12-09 15:46:00        0
# 4237      18226.0        6650.83         15 2010-11-26 15:51:00       13
# 4241      18231.0        4791.80         23 2010-10-29 14:17:00       41
# 4262      18260.0        7318.91         17 2010-11-30 12:25:00        9
#
#       Cluster
# 9          -1
# 25         -1
# 42         -1
# 48         -1
# ...

# %% [markdown]
# - Cluster -1 : (Monetary Outliers) -> Pamper
# - Cluster -2 : (Frequency Outliers) -> Upsell
# - Cluster -3 : (Monetary&Frequency Outliers) -> Delight
# - Pamper, Upsell, Delight
# - دلل، بيع إضافي، استمتع

# %%
cluster_colors = {
    -1:'#1f77b4',
    -2:'#ff7f0e',
    -3:'#2ca02c'
}
colors = outlier_clusters_df['Cluster'].map(cluster_colors)
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(projection="3d")
scatter = ax.scatter(outlier_clusters_df["MonetaryValue"], outlier_clusters_df["Frequency"], outlier_clusters_df["Recency"], c=colors)
ax.set_xlabel("Monetary Value")
ax.set_ylabel("Frequency")
ax.set_zlabel("Recency")
ax.set_title("3D Scatter for Customer Data")
plt.show()

# %%
cluster_labels ={
    0:'Retain',
    1:'Re-Engage',
    2:'Nurture',
    3:'Reward',
    -1:'Pamper',
    -2:'Upsell',
    -3:'Delight'
}

# %%
full_clustering_df = pd.concat([non_outliers_df, outlier_clusters_df])
full_clustering_df
# Out:
#       Customer ID  MonetaryValue  Frequency     LastInvoiceDate  Recency  \
# 0         12346.0         169.36          2 2010-06-28 13:53:00      164
# 1         12347.0        1323.32          2 2010-12-07 14:57:00        2
# 2         12348.0         221.16          1 2010-09-27 14:59:00       73
# 3         12349.0        2221.14          2 2010-10-28 08:23:00       42
# 4         12351.0         300.93          1 2010-11-29 15:23:00       10
# ...           ...            ...        ...                 ...      ...
# 4235      18223.0        7516.31         12 2010-11-17 12:20:00       22
# 4236      18225.0        7545.14         15 2010-12-09 15:46:00        0
# 4237      18226.0        6650.83         15 2010-11-26 15:51:00       13
# 4241      18231.0        4791.80         23 2010-10-29 14:17:00       41
# 4262      18260.0        7318.91         17 2010-11-30 12:25:00        9
#
#       Cluster
# 0           1
# 1           0
# 2           2
# 3           0
# ...

# %%
full_clustering_df['ClusterLabel'] = full_clustering_df['Cluster'].map(cluster_labels)
full_clustering_df
# Out:
#       Customer ID  MonetaryValue  Frequency     LastInvoiceDate  Recency  \
# 0         12346.0         169.36          2 2010-06-28 13:53:00      164
# 1         12347.0        1323.32          2 2010-12-07 14:57:00        2
# 2         12348.0         221.16          1 2010-09-27 14:59:00       73
# 3         12349.0        2221.14          2 2010-10-28 08:23:00       42
# 4         12351.0         300.93          1 2010-11-29 15:23:00       10
# ...           ...            ...        ...                 ...      ...
# 4235      18223.0        7516.31         12 2010-11-17 12:20:00       22
# 4236      18225.0        7545.14         15 2010-12-09 15:46:00        0
# 4237      18226.0        6650.83         15 2010-11-26 15:51:00       13
# 4241      18231.0        4791.80         23 2010-10-29 14:17:00       41
# 4262      18260.0        7318.91         17 2010-11-30 12:25:00        9
#
#       Cluster ClusterLabel
# 0           1    Re-Engage
# 1           0       Retain
# ...

# %%
counts = full_clustering_df['ClusterLabel'].value_counts()
full_clustering_df['MonetaryValue per 100'] = full_clustering_df['MonetaryValue'] / 100
# ترتيب الفئات بحسب عدد العناصر (تنازلياً)
ordered_labels = counts.index

# رسم countplot مع ترتيب الفئات
sns.countplot(data=full_clustering_df, x='ClusterLabel', order=ordered_labels, palette='Set2')
#sns.countplot(data=full_clustering_df, x=full_clustering_df.ClusterLabel, palette='Set2' )
sns.lineplot(data=full_clustering_df.groupby('ClusterLabel')[['Recency','Frequency','MonetaryValue per 100']].mean(), markers='o')
# Out:
# C:\Users\aa\AppData\Local\Temp\ipykernel_6480\1162354079.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=full_clustering_df, x='ClusterLabel', order=ordered_labels, palette='Set2')
# C:\Users\aa\AppData\Local\Temp\ipykernel_6480\1162354079.py:9: UserWarning:
# The markers list has fewer values (1) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(data=full_clustering_df.groupby('ClusterLabel')[['Recency','Frequency','MonetaryValue per 100']].mean(), markers='o')
# <Axes: xlabel='ClusterLabel', ylabel='count'>

# %%
full_clustering_df.groupby('ClusterLabel')[['Recency','Frequency','MonetaryValue']].mean()
# Out:
#                  Recency  Frequency  MonetaryValue
# ClusterLabel
# Delight        14.451327  25.867257   17147.663832
# Nurture        54.066044   1.644430     417.954203
# Pamper         47.913706   7.187817    6498.451827
# Re-Engage     251.165188   1.429047     384.536644
# Retain         49.725383   3.911379    1308.624695
# Reward         33.888664   7.242915    2436.092091
# Upsell         23.075472  15.037736    2734.687547

# %%
import matplotlib.pyplot as plt
import seaborn as sns

full_clustering_df['MonetaryValue per 100'] = full_clustering_df['MonetaryValue'] / 100
# حساب وترتيب الفئات
counts = full_clustering_df['ClusterLabel'].value_counts()
ordered_labels = counts.index

# حساب المتوسطات لكل ClusterLabel وترتيبها
cluster_means = full_clustering_df.groupby('ClusterLabel')[['Recency', 'Frequency', 'MonetaryValue per 100']].mean().loc[ordered_labels]

fig, ax1 = plt.subplots(figsize=(12,6))

# رسم countplot على المحور الأول (الأساسي)
sns.barplot(x=counts.index, y=counts.values, ax=ax1, palette='Set2')
ax1.set_xlabel('ClusterLabel')
ax1.set_ylabel('Count')
ax1.set_title('عدد العينات ومتوسطات Recency، Frequency، MonetaryValue لكل Cluster')

# إنشاء محور ثاني لمتوسطات المتغيرات
ax2 = ax1.twinx()

# رسم lineplot للمتوسطات على المحور الثاني
for col in cluster_means.columns:
    ax2.plot(cluster_means.index, cluster_means[col], marker='o', label=col)

ax2.set_ylabel('Mean Values')
ax2.legend(title='Metrics')

plt.show()
# Out:
# C:\Users\aa\AppData\Local\Temp\ipykernel_6480\4122114145.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=counts.index, y=counts.values, ax=ax1, palette='Set2')
